# %% [markdown]
# # Support Vector Machine
#
# * Objective: classify vectors into positive and negative samples based on labled training data
# * Collection of input vectors $\mathbf x_i$ for $i=1,\dots,N$ and $\mathbf x_i \in {\rm I\!R}^m$
# * For every $\mathbf x_i$ in the training data set we have a label $y_i$ (+1 or -1).

# %% [markdown]
# * `x[i,:]` corresponds to $\vec x_i$

# %% [markdown]
# The dots are the input vectors $\vec x_i$ and the color represent the labels $y_i$

# %% [markdown]
# In Ubuntu/Debian install also the package `libnlopt-dev`:
#
# ```bash
# sudo apt install libnlopt-dev
# ```

# %%
using PyPlot
using NLopt
using LinearAlgebra

# %%
x = [-2 4;
     4  1;
     1  6;
     2  4;
     6  3;
     -1  3]

y = [-1,-1,1,1,1,-1]

function plotdata(x,y)
  ind = findall(y .== -1)
  plot(x[ind,1],x[ind,2],"ro")
  ind = findall(y .== 1)
  plot(x[ind,1],x[ind,2],"bo")
  axis("equal")
end

plotdata(x,y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (-2.4, 6.4, 0.75, 6.25)

# %%
function plotline(w,b;kwargs...)
  t = -2:6
  plot(t,-(b .+ w[1]*t)/w[2]; kwargs...)
end

plotdata(x,y)
plotline([0.5, 1], -4; color = "g")
plotline([0.5, 1], -5; color = "k", linestyle=":")
plotline([0.5, 1], -3; color = "k", linestyle=":")
arrow(0,0,0.5, 1; head_width=0.1, head_length=0.2, length_includes_head = true )
annotate("w",[0,0]; xytext=(-5, 15), textcoords = "offset points", fontweight = "bold")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(-5, 15, 'w')

# %% [markdown]
# Note that all lines are perpendicular to the vector $\vec w$.

# %% [markdown]
# For any positive samples:
#
# $$
#  \mathbf w^T \mathbf x_+ + b \ge 1
# $$
#
# For any negative samples:
#
# $$
#  \mathbf w^T \mathbf x_- + b \le -1
# $$

# %% [markdown]
# For two samples at the limit of this "road" ($\mathbf x_+$ and $\mathbf x_-$) we have:
#
# $$
#  \mathbf w^T \mathbf x_+ + b = 1 \\
#  \mathbf w^T \mathbf x_- + b = -1
# $$
#
#
# The width of the "road" is computed by projecting the vector $(\mathbf x_+ - \mathbf x_-)$
# to a normal vector perpendicular to the central line (vector $\frac{\mathbf w}{\| \mathbf w \|}$):
#
# $$
# \left|(\mathbf x_+ - \mathbf x_-)^T  \frac{\mathbf w}{\| \mathbf w \|} \right| =
# \left|\mathbf x_+^T \mathbf w - \mathbf x_-^T \mathbf w \right| \frac{1}{\| \mathbf w \|}  =
# \left|1-b - (-1 -b) \right|  \frac{1}{\| \mathbf w \|}  =
# \frac{2}{\|\mathbf w\|}
# $$
#
#
#
# Maximize $ \frac{2}{\|\mathbf w\|}$ under the inequality constrain:
#
# $$
#  y_i (\mathbf w^T \mathbf x_i + b) \ge 1
# $$
#
#
# Maximizing $ \frac{2}{\|\mathbf w\|}$ is the same as minimizing $\frac{1}{2} \| \mathbf w \|^2$.
#
# The contraint is introduced using the Lagrange multipliers $\alpha_i$ ([Karush–Kuhn–Tucker conditions](https://en.wikipedia.org/wiki/Karush%E2%80%93Kuhn%E2%80%93Tucker_conditions))
#
# $$
# L(\mathbf w,b,\alpha_1,\alpha_2,...) = \frac{1}{2} \| \mathbf w \|^2 - \sum_i \alpha_i ( y_i (\mathbf w^T \mathbf x_i + b) -1 )
# $$
#
# $$
# \frac{\partial L}{\partial \mathbf w} = \mathbf w - \sum_i \alpha_i y_i \mathbf x_i = 0
# $$
#
# Thus $\mathbf w$ is a linear sum of the samples $\mathbf x_i$:
#
# $$
# \mathbf w = \sum_i \alpha_i y_i \mathbf x_i
# $$
#
# $$
# \frac{\partial L}{\partial b} = -\sum_i \alpha_i y_i = 0 \rightarrow \sum_i \alpha_i y_i = 0
# $$
#
# $$
# L = \frac{1}{2} \left( \sum_i \alpha_i y_i \mathbf x_i^T \right)  \left( \sum_j \alpha_j y_j \mathbf x_j \right)
# -
# \sum_i \alpha_i  y_i  \mathbf x_i^T \left(\sum_j \alpha_j y_j \mathbf x_j \right)
# - b \sum_i \alpha_i y_i
# + \sum_i \alpha_i
# $$
#
# Maximum of
#
# $$
# L = \sum_i \alpha_i
# - \frac{1}{2}
# \sum_i \sum_j
# \alpha_i \alpha_j y_i y_j \mathbf x_i^T \mathbf x_j
# $$
#
# with the contraints $\alpha_i \ge 0$ and $\sum_i \alpha_i y_i = 0$.
# * It depends only on the dot product of pairs of samples $\mathbf x_i^T \mathbf x_j$
# * maximization of $L$ is a convex problem -> there is only one maximum (no local maximum)
#
# Decision rule
#
# $$
# \mbox{if}\;\;
# \sum_i \alpha_i  y_i  \mathbf x_i^T \mathbf u > 0 \;\;\mbox{then $\mathbf u$ is a positive sample}
# $$
#
# Or a negative sample otherwise.

# %% [markdown]
# To compute $b$, we can use any $i$ (for which $\alpha_i > 0$):
#
# $$
# y_i (\vec w^T \vec x_i + b) - 1 = 0
# $$
#
# or
# $$
# b = y_i - \vec w^T \vec x_i
# $$

# %%
function L(α,x,y)
    N = length(y)
    Lval = sum(α)
    for j = 1:N
       for i = 1:N
           Lval -= 0.5 * α[i] * α[j] * y[i] * y[j] * (x[i,:] ⋅ x[j,:]) 
        end
    end
    #@show α,Lval
    return Lval
end

using NLopt
N = length(y)
#opt = Opt(:GN_DIRECT, N)
opt = Opt(:LN_COBYLA, N)
#opt = Opt(:LD_MMA, N)

max_objective!(opt, (α,grad) -> L(α,x,y))
lower_bounds!(opt, zeros(N))
equality_constraint!(opt, (α,grad) -> sum(y.*α))

xtol_rel!(opt,1e-6)
maxeval!(opt,10000)

minL,α,ret = optimize(opt, ones(N))
# Out:
# (0.6249999999932578, [0.2916677599437004, 0.33333386811399474, 3.4711640783697557e-23, 0.6250016280576951, 1.82641479164194e-21, 2.74520565571948e-22], :XTOL_REACHED)

# %% [markdown]
# Points travers by the dottes black line are called support vectors.
# $\vec x_i$ is a support vector if $\alpha_i > 0$ (i.e. if $\alpha_i$ is *different* from zero).

# %% [markdown]
# Compute $\vec w$ and $b$:

# %%
w = zeros(size(x,2))
for i = 1:N
   w += α[i] * y[i] * x[i,:]
end

# index of a support vector
i = findfirst(α .> eps()) # for any i such that α[i] > 0
b = y[i] - w' * x[i,:]

@show w,b
# Out:
# (w, b) = ([0.5000033035468121, 1.000001604341984], -3.9999998102743115)
# ([0.5000033035468121, 1.000001604341984], -3.9999998102743115)

# %% [markdown]
# Width of the "road":

# %%
2/norm(w)
# Out:
# 1.7888497222353612

# %% [markdown]
# All support vectors are marked by a cross:

# %%
plotdata(x,y)
plotline(w,b)
plotline(w,b-1; color = "k", linestyle=":")
plotline(w,b+1; color = "k", linestyle=":")

isupport = findall(α .> eps())
plot(x[isupport,1],x[isupport,2],"x",color="k");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# If sample are not linearily separable, then one can introduce a transformation function $\vec \phi(\vec x)$ such that the transformed samples are separable.
#
# Kernel $K$
#
# $$
# K(\vec x_i,\vec x_j) = \phi(\vec x_i)^T \phi(\vec x_j)
# $$
#
# Possible kernels:
#
# * $K(\vec u,\vec v) = (\vec u^T \vec v + 1)^n$
# * $K(\vec u,\vec v) = \exp(- \| \vec u - \vec v \| / \sigma ) $
